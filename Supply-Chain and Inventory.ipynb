# %%
import pandas as pd
import numpy as np

products = pd.read_csv("C:/Users/gupta/Downloads/products.csv")
suppliers = pd.read_csv("C:/Users/gupta/Downloads/suppliers.csv")
customers = pd.read_csv("C:/Users/gupta/Downloads/customers.csv")
inventory = pd.read_csv("C:/Users/gupta/Downloads/inventory.csv")
sales = pd.read_csv("C:/Users/gupta/Downloads/sales_transaction.csv")

# %%
products.head(10)
# Out:
#    product_id           product_name      brand   category sub_category  \
# 0           1             HUL Paneer        HUL      Dairy       Paneer
# 1           2              Tata Atta       Tata    Grocery         Atta
# 2           3            Amul Bottle       Amul    Kitchen       Bottle
# 3           4             Dabur Milk      Dabur      Dairy         Milk
# 4           5  Patanjali Baby Lotion  Patanjali  Baby Care  Baby Lotion
# 5           6               ITC Atta        ITC    Grocery         Atta
# 6           7         Amul Baby Soap       Amul  Baby Care    Baby Soap
# 7           8         Fortune Paneer    Fortune      Dairy       Paneer
# 8           9    Sunfeast Soft Drink   Sunfeast  Beverages   Soft Drink
# 9          10              Nivea Tea      Nivea    Grocery          Tea
#
#    supplier_id  cost_price  selling_price  gst_percent  shelf_life_days  \
# 0          170     1591.86        2236.94           12               90
# ...

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   product_id        8000 non-null   int64
#  1   product_name      8000 non-null   object
#  2   brand             8000 non-null   object
#  3   category          8000 non-null   object
#  4   sub_category      8000 non-null   object
#  5   supplier_id       8000 non-null   int64
#  6   cost_price        8000 non-null   float64
#  7   selling_price     8000 non-null   float64
#  8   gst_percent       8000 non-null   int64
#  9   shelf_life_days   8000 non-null   int64
#  10  reorder_level     8000 non-null   int64
#  11  reorder_quantity  8000 non-null   int64
#  12  weight            8000 non-null   float64
#  13  unit              8000 non-null   object
#  14  launch_date       8000 non-null   object
#  15  status            8000 non-null   object
# ...

# %%
products.describe()
# Out:
#        product_id  supplier_id   cost_price  selling_price  gst_percent  \
# count  8000.00000  8000.000000  8000.000000    8000.000000  8000.000000
# mean   4000.50000   250.846000   910.144896    1214.081411     8.904125
# std    2309.54541   143.655616   517.617545     702.341773     6.855148
# min       1.00000     1.000000    15.060000      20.420000     0.000000
# 25%    2000.75000   127.000000   455.680000     606.190000     5.000000
# 50%    4000.50000   252.000000   912.450000    1206.575000    12.000000
# 75%    6000.25000   373.000000  1356.817500    1800.842500    18.000000
# max    8000.00000   500.000000  1800.000000    2783.220000    18.000000
#
#        shelf_life_days  reorder_level  reorder_quantity       weight
# count       8000.00000    8000.000000       8000.000000  8000.000000
# mean         144.39875      69.873625        273.788875     5.092140
# std          120.64235      29.114728        130.421480     2.853314
# ...

# %%
products.isnull().sum()
# Out:
# product_id          0
# product_name        0
# brand               0
# category            0
# sub_category        0
# supplier_id         0
# cost_price          0
# selling_price       0
# gst_percent         0
# shelf_life_days     0
# reorder_level       0
# reorder_quantity    0
# weight              0
# unit                0
# launch_date         0
# status              0
# dtype: int64

# %%
products.duplicated().sum()
# Out:
# np.int64(0)

# %%
products.drop_duplicates(inplace=True)

# %%
products.nunique()
# Out:
# product_id          8000
# product_name         952
# brand                 20
# category               9
# sub_category          48
# supplier_id          500
# cost_price          7816
# selling_price       7886
# gst_percent            4
# shelf_life_days        5
# reorder_level        101
# reorder_quantity     451
# weight               991
# unit                   5
# launch_date         2139
# status                 2
# dtype: int64

# %%
# Missing Value Percentage

missing = pd.DataFrame({
    'Missing Values': products.isnull().sum(),
    'Percentage': round(products.isnull().mean()*100,2)
})

missing
# Out:
#                   Missing Values  Percentage
# product_id                     0         0.0
# product_name                   0         0.0
# brand                          0         0.0
# category                       0         0.0
# sub_category                   0         0.0
# supplier_id                    0         0.0
# cost_price                     0         0.0
# selling_price                  0         0.0
# gst_percent                    0         0.0
# shelf_life_days                0         0.0
# reorder_level                  0         0.0
# reorder_quantity               0         0.0
# weight                         0         0.0
# unit                           0         0.0
# launch_date                    0         0.0
# status                         0         0.0

# %%
products.columns = (
    products.columns
            .str.strip()
            .str.lower()
            .str.replace(" ", "_")
)

products.columns
# Out:
# Index(['product_id', 'product_name', 'brand', 'category', 'sub_category',
#        'supplier_id', 'cost_price', 'selling_price', 'gst_percent',
#        'shelf_life_days', 'reorder_level', 'reorder_quantity', 'weight',
#        'unit', 'launch_date', 'status'],
#       dtype='object')

# %%
products['launch_date'] = pd.to_datetime(products['launch_date'])

products.dtypes
# Out:
# product_id                   int64
# product_name                object
# brand                       object
# category                    object
# sub_category                object
# supplier_id                  int64
# cost_price                 float64
# selling_price              float64
# gst_percent                  int64
# shelf_life_days              int64
# reorder_level                int64
# reorder_quantity             int64
# weight                     float64
# unit                        object
# launch_date         datetime64[ns]
# status                      object
# dtype: object

# %%
products[products['cost_price'] < 0]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, brand, category, sub_category, supplier_id, cost_price, selling_price, gst_percent, shelf_life_days, reorder_level, reorder_quantity, weight, unit, launch_date, status]
# Index: []

# %%
products[products['selling_price'] < 0]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, brand, category, sub_category, supplier_id, cost_price, selling_price, gst_percent, shelf_life_days, reorder_level, reorder_quantity, weight, unit, launch_date, status]
# Index: []

# %%
products[
    products['selling_price'] <
    products['cost_price']
]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, brand, category, sub_category, supplier_id, cost_price, selling_price, gst_percent, shelf_life_days, reorder_level, reorder_quantity, weight, unit, launch_date, status]
# Index: []

# %%
products[
    products['weight'] < 0
]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, brand, category, sub_category, supplier_id, cost_price, selling_price, gst_percent, shelf_life_days, reorder_level, reorder_quantity, weight, unit, launch_date, status]
# Index: []

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
plt.boxplot(products['cost_price'])
plt.title("Cost Price Outliers")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.boxplot(products['weight'])
plt.title("Weight Outliers")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.boxplot(products['selling_price'])
plt.title("Selling Price Outliers")
plt.show()

# %%
products.shape
# Out:
# (8000, 16)

# %%
suppliers.sample(5, random_state=42)
# Out:
#      supplier_id                   supplier_name supplier_type        city  \
# 361          362  Edwin, Bhagat and Nath Pvt Ltd  Manufacturer   Ahmedabad
# 73            74               Patel Inc Pvt Ltd      Importer   Bengaluru
# 374          375            Iyengar-Deep Pvt Ltd  Manufacturer  Coimbatore
# 155          156              Nayak-Babu Pvt Ltd  Manufacturer     Kolkata
# 104          105                Gill LLC Pvt Ltd   Distributor   Bengaluru
#
#            state  contact_person       phone                            email  \
# 361      Gujarat  Vrishti Suresh  8399675940                anmol60@wable.org
# 73     Karnataka      Jagat Ravi  3463234112             tanmayikale@bawa.com
# 374   Tamil Nadu      Lopa Singh  1568366537          kala66@mahal-sahota.com
# 155  West Bengal     Fitan Dutta  3548083685  parikhpatrick@raval-sachdev.com
# 104    Karnataka      Ojasvi Tak  6893678493    nadigikshita@pingle-parsa.com
#
# ...

# %%
suppliers.columns
# Out:
# Index(['supplier_id', 'supplier_name', 'supplier_type', 'city', 'state',
#        'contact_person', 'phone', 'email', 'rating', 'lead_time_days',
#        'payment_terms_days', 'defect_rate_percent',
#        'on_time_delivery_percent'],
#       dtype='object')

# %%
suppliers.describe()
# Out:
#        supplier_id         phone      rating  lead_time_days  \
# count   500.000000  5.000000e+02  500.000000      500.000000
# mean    250.500000  5.205775e+09    3.724200        8.240000
# std     144.481833  2.882451e+09    0.724295        3.724264
# min       1.000000  4.526142e+07    2.500000        2.000000
# 25%     125.750000  2.793843e+09    3.100000        5.000000
# 50%     250.500000  5.230469e+09    3.700000        8.000000
# 75%     375.250000  7.632208e+09    4.300000       12.000000
# max     500.000000  9.991542e+09    5.000000       14.000000
#
#        payment_terms_days  defect_rate_percent  on_time_delivery_percent
# count          500.000000           500.000000                 500.00000
# mean            38.640000             2.379000                  90.70542
# std             16.694544             1.296212                   4.94944
# min             15.000000             0.120000                  82.01000
# ...

# %%
suppliers.nunique()
# Out:
# supplier_id                 500
# supplier_name               500
# supplier_type                 4
# city                         17
# state                        10
# contact_person              499
# phone                       500
# email                       500
# rating                       26
# lead_time_days               13
# payment_terms_days            4
# defect_rate_percent         297
# on_time_delivery_percent    435
# dtype: int64

# %%
suppliers.isnull().sum()
# Out:
# supplier_id                 0
# supplier_name               0
# supplier_type               0
# city                        0
# state                       0
# contact_person              0
# phone                       0
# email                       0
# rating                      0
# lead_time_days              0
# payment_terms_days          0
# defect_rate_percent         0
# on_time_delivery_percent    0
# dtype: int64

# %%
suppliers.duplicated().sum()
# Out:
# np.int64(0)

# %%
suppliers.columns = (
    suppliers.columns
             .str.strip()
             .str.lower()
             .str.replace(" ", "_")
)

suppliers.columns
# Out:
# Index(['supplier_id', 'supplier_name', 'supplier_type', 'city', 'state',
#        'contact_person', 'phone', 'email', 'rating', 'lead_time_days',
#        'payment_terms_days', 'defect_rate_percent',
#        'on_time_delivery_percent'],
#       dtype='object')

# %%
suppliers['city'] = suppliers['city'].replace({
    'Bombay':'Mumbai',
    'Bangalore':'Bengaluru',
    'Hyderbad':'Hyderabad'
})

# %%
suppliers[
    (suppliers['rating'] < 0) |
    (suppliers['rating'] > 5)
]
# Out:
# Empty DataFrame
# Columns: [supplier_id, supplier_name, supplier_type, city, state, contact_person, phone, email, rating, lead_time_days, payment_terms_days, defect_rate_percent, on_time_delivery_percent]
# Index: []

# %%
suppliers[
    suppliers['on_time_delivery_percent'] > 100
]
suppliers[
    suppliers['on_time_delivery_percent'] > 100
]
# Out:
# Empty DataFrame
# Columns: [supplier_id, supplier_name, supplier_type, city, state, contact_person, phone, email, rating, lead_time_days, payment_terms_days, defect_rate_percent, on_time_delivery_percent]
# Index: []

# %%
plt.figure(figsize=(6,4))
plt.boxplot(suppliers['rating'])
plt.title("Supplier Rating")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.boxplot(suppliers['defect_rate_percent'])
plt.title("Defect Rate")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.boxplot(suppliers['on_time_delivery_percent'])
plt.title("On-Time Delivery %")
plt.show()

# %%
numerical_columns = [
    'rating',
    'lead_time_days',
    'payment_terms_days',
    'defect_rate_percent',
    'on_time_delivery_percent'
]

for col in numerical_columns:

    Q1 = suppliers[col].quantile(0.25)
    Q3 = suppliers[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = suppliers[
        (suppliers[col] < lower) |
        (suppliers[col] > upper)
    ]

    print(f"{col}: {len(outliers)} outliers")
# Out:
# rating: 0 outliers
# lead_time_days: 0 outliers
# payment_terms_days: 0 outliers
# defect_rate_percent: 0 outliers
# on_time_delivery_percent: 0 outliers

# %%
customers.sample(5, random_state=45)
# Out:
#        customer_id  customer_name  gender  age       city        state  \
# 9545          9546    Balvan Vyas    Male   21       Pune  Maharashtra
# 22564        22565      Pahal Sur    Male   30  New Delhi        Delhi
# 31942        31943  Chasmum Kapur  Female   64  Ahmedabad      Gujarat
# 30562        30563  Teerth Mannan    Male   20      Surat      Gujarat
# 7878          7879     Falak Kata    Male   36      Surat      Gujarat
#
#        pincode customer_type registration_date  loyalty_points  \
# 9545     60785        Retail        2023-05-25            1672
# 22564   139519        Retail        2026-05-29            2260
# 31942   484988     Wholesale        2021-03-21            4731
# 30562   546170        Retail        2021-05-01            1480
# 7878    505072        Retail        2023-03-15             878
#
#       preferred_payment  annual_income marital_status  \
# 9545        Credit Card         404015         Single
# ...

# %%
customers.dtypes
# Out:
# customer_id            int64
# customer_name         object
# gender                object
# age                    int64
# city                  object
# state                 object
# pincode                int64
# customer_type         object
# registration_date     object
# loyalty_points         int64
# preferred_payment     object
# annual_income          int64
# marital_status        object
# email                 object
# phone                float64
# dtype: object

# %%
customers.describe()
# Out:
#         customer_id           age        pincode  loyalty_points  \
# count  50100.000000  50100.000000   50100.000000    50100.000000
# mean   25001.254431     43.932575  499548.702595     2504.853872
# std    14434.617343     15.341613  288033.508329     1448.116484
# min        1.000000     18.000000      10.000000        0.000000
# 25%    12501.750000     31.000000  251651.500000     1248.000000
# 50%    25002.500000     44.000000  496667.000000     2505.000000
# 75%    37501.250000     57.000000  748773.250000     3763.250000
# max    50000.000000     70.000000  999974.000000     5000.000000
#
#        annual_income         phone
# count   5.010000e+04  4.959300e+04
# mean    9.222955e+05  5.017733e+09
# std     6.901312e+05  2.877288e+09
# min     2.500060e+05  1.208010e+05
# 25%     5.218892e+05  2.527093e+09
# 50%     7.900790e+05  5.031512e+09
# 75%     1.048282e+06  7.512729e+09
# max     4.997877e+06  9.999998e+09

# %%
customers.isnull().sum()
# Out:
# customer_id            0
# customer_name          0
# gender                 0
# age                    0
# city                   0
# state                  0
# pincode                0
# customer_type          0
# registration_date      0
# loyalty_points         0
# preferred_payment      0
# annual_income          0
# marital_status         0
# email                  0
# phone                507
# dtype: int64

# %%
customers["phone"] = customers["phone"].astype("string")
customers["phone"] = customers["phone"].fillna("Not Available")

# %%
customers.isnull().sum()
# Out:
# customer_id          0
# customer_name        0
# gender               0
# age                  0
# city                 0
# state                0
# pincode              0
# customer_type        0
# registration_date    0
# loyalty_points       0
# preferred_payment    0
# annual_income        0
# marital_status       0
# email                0
# phone                0
# dtype: int64

# %%
customers.duplicated().sum()
# Out:
# np.int64(100)

# %%
duplicate_count = customers.duplicated().sum()

if duplicate_count > 0:
    customers.drop_duplicates(inplace=True)
    print(f"{duplicate_count} duplicate rows removed.")
else:
    print("No duplicate rows found.")
# Out:
# 100 duplicate rows removed.

# %%
customers.columns = (
    customers.columns
             .str.strip()
             .str.lower()
             .str.replace(" ", "_")
)

customers.columns
# Out:
# Index(['customer_id', 'customer_name', 'gender', 'age', 'city', 'state',
#        'pincode', 'customer_type', 'registration_date', 'loyalty_points',
#        'preferred_payment', 'annual_income', 'marital_status', 'email',
#        'phone'],
#       dtype='object')

# %%
customers["customer_name"] = customers["customer_name"].str.title()

customers["city"] = customers["city"].str.title()

customers["state"] = customers["state"].str.title()

customers["customer_type"] = customers["customer_type"].str.title()

customers["preferred_payment"] = customers["preferred_payment"].str.title()

customers["marital_status"] = customers["marital_status"].str.title()

customers["gender"] = customers["gender"].str.title()

# %%
customers.columns
# Out:
# Index(['customer_id', 'customer_name', 'gender', 'age', 'city', 'state',
#        'pincode', 'customer_type', 'registration_date', 'loyalty_points',
#        'preferred_payment', 'annual_income', 'marital_status', 'email',
#        'phone'],
#       dtype='object')

# %%
customers["city"] = customers["city"].replace({
    "Bombay":"Mumbai",
    "Bangalore":"Bengaluru",
    "Hyderbad":"Hyderabad"
})

# %%
customers["registration_date"] = pd.to_datetime(customers["registration_date"])

# %%
customers[
    (customers["age"] < 18) |
    (customers["age"] > 100)
]
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_name, gender, age, city, state, pincode, customer_type, registration_date, loyalty_points, preferred_payment, annual_income, marital_status, email, phone]
# Index: []

# %%
customers[
    customers["annual_income"] < 0
]
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_name, gender, age, city, state, pincode, customer_type, registration_date, loyalty_points, preferred_payment, annual_income, marital_status, email, phone]
# Index: []

# %%
customers["gender"].value_counts()
# Out:
# gender
# Male      25039
# Female    24961
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
plt.boxplot(customers["age"])
plt.title("Age")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.boxplot(customers["annual_income"])
plt.title("Annual Income")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.boxplot(customers["loyalty_points"])
plt.title("Loyalty Points")
plt.show()

# %%
numerical_columns = [
    "age",
    "annual_income",
    "loyalty_points"
]

for col in numerical_columns:

    Q1 = customers[col].quantile(0.25)
    Q3 = customers[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = customers[
        (customers[col] < lower) |
        (customers[col] > upper)
    ]

    print(f"{col}: {len(outliers)} outliers")
# Out:
# age: 0 outliers
# annual_income: 3883 outliers
# loyalty_points: 0 outliers

# %%
customers["annual_income"].describe()
# Out:
# count    5.000000e+04
# mean     9.225832e+05
# std      6.905516e+05
# min      2.500060e+05
# 25%      5.219578e+05
# 50%      7.902430e+05
# 75%      1.048336e+06
# max      4.997877e+06
# Name: annual_income, dtype: float64

# %%
customers["annual_income"].max()
# Out:
# 4997877

# %%
# Annual income shows many statistical outliers according to the IQR method.
# However, these values are realistic for high-income customers and are retained
# because they represent valid business data rather than data entry errors.

# %%
inventory.tail()
# Out:
#         inventory_id  warehouse_id  product_id  opening_stock  received_stock  \
# 120195         96979            17        6036            189              78
# 120196         69350            22        4002            325             180
# 120197          3065             9        4069            260             230
# 120198         28145            13        2701            179              97
# 120199         51387            11        6644             12             264
#
#         sold_stock  returned_stock  damaged_stock  closing_stock  unit_cost  \
# 120195          10               3              9            251     267.64
# 120196         163               0             10            332    1065.24
# 120197         241               9              7            251     913.23
# 120198         226              15              2             63     255.53
# 120199          99               2              3            176      35.18
#
# ...

# %%
inventory.columns
# Out:
# Index(['inventory_id', 'warehouse_id', 'product_id', 'opening_stock',
#        'received_stock', 'sold_stock', 'returned_stock', 'damaged_stock',
#        'closing_stock', 'unit_cost', 'stock_value', 'last_updated',
#        'reorder_flag', 'warehouse_capacity_utilization'],
#       dtype='object')

# %%
inventory.dtypes
# Out:
# inventory_id                        int64
# warehouse_id                        int64
# product_id                          int64
# opening_stock                       int64
# received_stock                      int64
# sold_stock                          int64
# returned_stock                      int64
# damaged_stock                       int64
# closing_stock                       int64
# unit_cost                         float64
# stock_value                       float64
# last_updated                       object
# reorder_flag                       object
# warehouse_capacity_utilization    float64
# dtype: object

# %%
inventory.describe()
# Out:
#         inventory_id   warehouse_id     product_id  opening_stock  \
# count  120200.000000  120200.000000  120200.000000  120200.000000
# mean    59993.584942      13.001697    3999.358220     249.473145
# std     34644.982737       7.219660    2312.939355     144.616228
# min         1.000000       1.000000       1.000000       0.000000
# 25%     29984.750000       7.000000    1995.000000     124.000000
# 50%     59989.500000      13.000000    4009.500000     249.000000
# 75%     89996.250000      19.000000    6003.000000     375.000000
# max    120000.000000      25.000000    8000.000000     500.000000
#
#        received_stock     sold_stock  returned_stock  damaged_stock  \
# count   120200.000000  120200.000000   120200.000000  120200.000000
# mean       150.259409     116.108735        7.497280       5.008502
# std         86.757936      72.001113        4.611622       3.155192
# min          0.000000       0.000000        0.000000       0.000000
# ...

# %%
inventory.columns = (
    inventory.columns
        .str.strip()
        .str.lower()
        .str.replace(" ", "_")
)

inventory.columns
# Out:
# Index(['inventory_id', 'warehouse_id', 'product_id', 'opening_stock',
#        'received_stock', 'sold_stock', 'returned_stock', 'damaged_stock',
#        'closing_stock', 'unit_cost', 'stock_value', 'last_updated',
#        'reorder_flag', 'warehouse_capacity_utilization'],
#       dtype='object')

# %%
text_columns = inventory.select_dtypes(include="object").columns

for col in text_columns:
    inventory[col] = inventory[col].str.strip().str.title()

# %%
inventory["last_updated"] = pd.to_datetime(
    inventory["last_updated"]
)

# %%
inventory.dtypes
# Out:
# inventory_id                               int64
# warehouse_id                               int64
# product_id                                 int64
# opening_stock                              int64
# received_stock                             int64
# sold_stock                                 int64
# returned_stock                             int64
# damaged_stock                              int64
# closing_stock                              int64
# unit_cost                                float64
# stock_value                              float64
# last_updated                      datetime64[ns]
# reorder_flag                              object
# warehouse_capacity_utilization           float64
# dtype: object

# %%
inventory.isnull().sum()
# Out:
# inventory_id                        0
# warehouse_id                        0
# product_id                          0
# opening_stock                       0
# received_stock                      0
# sold_stock                          0
# returned_stock                      0
# damaged_stock                       0
# closing_stock                       0
# unit_cost                           0
# stock_value                       320
# last_updated                        0
# reorder_flag                        0
# warehouse_capacity_utilization      0
# dtype: int64

# %%
inventory["stock_value"] = (
    inventory["closing_stock"] *
    inventory["unit_cost"]
)

# %%
inventory.isnull().sum()
# Out:
# inventory_id                      0
# warehouse_id                      0
# product_id                        0
# opening_stock                     0
# received_stock                    0
# sold_stock                        0
# returned_stock                    0
# damaged_stock                     0
# closing_stock                     0
# unit_cost                         0
# stock_value                       0
# last_updated                      0
# reorder_flag                      0
# warehouse_capacity_utilization    0
# dtype: int64

# %%
inventory["calculated_closing_stock"] = (
    inventory["opening_stock"] +
    inventory["received_stock"] +
    inventory["returned_stock"] -
    inventory["sold_stock"] -
    inventory["damaged_stock"]
)

inventory[
    inventory["closing_stock"] != inventory["calculated_closing_stock"]
]
# Out:
#         inventory_id  warehouse_id  product_id  opening_stock  received_stock  \
# 367              368             7        2071             58              92
# 387              388             9        3348             96               2
# 525              526            20         195             47              29
# 619              620            10        3013             10              17
# 694              695            14        4404            492             284
# ...              ...           ...         ...            ...             ...
# 116752        116753             8        2984              8               7
# 119025        119026             9        2025             37               2
# 119469        119470            22        7702             21               4
# 119516        119517             6        4585              5               3
# 119754        119755            11        4135            364             207
#
# ...

# %%
inventory[inventory["opening_stock"] < 0]
# Out:
# Empty DataFrame
# Columns: [inventory_id, warehouse_id, product_id, opening_stock, received_stock, sold_stock, returned_stock, damaged_stock, closing_stock, unit_cost, stock_value, last_updated, reorder_flag, warehouse_capacity_utilization, calculated_closing_stock]
# Index: []

# %%
inventory["calculated_closing_stock"] = (
    inventory["opening_stock"] +
    inventory["received_stock"] +
    inventory["returned_stock"] -
    inventory["sold_stock"] -
    inventory["damaged_stock"]
)

invalid_inventory = inventory[
    inventory["calculated_closing_stock"] < 0
]

print(f"Invalid inventory records: {len(invalid_inventory)}")
# Out:
# Invalid inventory records: 234

# %%
available_stock = (
    inventory["opening_stock"]
    + inventory["received_stock"]
    + inventory["returned_stock"]
    - inventory["damaged_stock"]
)

mask = inventory["calculated_closing_stock"] < 0

inventory.loc[mask, "sold_stock"] = available_stock[mask].clip(lower=0)

inventory["closing_stock"] = (
    inventory["opening_stock"]
    + inventory["received_stock"]
    + inventory["returned_stock"]
    - inventory["sold_stock"]
    - inventory["damaged_stock"]
)

inventory["stock_value"] = (
    inventory["closing_stock"]
    * inventory["unit_cost"]
)

# %%
inventory["stock_value"] = (
    inventory["closing_stock"] *
    inventory["unit_cost"]
)

# %%
inventory.drop(columns="calculated_closing_stock", inplace=True)

# %%
inventory["calculated_closing_stock"] = (
    inventory["opening_stock"] +
    inventory["received_stock"] +
    inventory["returned_stock"] -
    inventory["sold_stock"] -
    inventory["damaged_stock"]
)

inventory[
    inventory["closing_stock"] != inventory["calculated_closing_stock"]
]
# Out:
# Empty DataFrame
# Columns: [inventory_id, warehouse_id, product_id, opening_stock, received_stock, sold_stock, returned_stock, damaged_stock, closing_stock, unit_cost, stock_value, last_updated, reorder_flag, warehouse_capacity_utilization, calculated_closing_stock]
# Index: []

# %%
inventory.head(15)
# Out:
#     inventory_id  warehouse_id  product_id  opening_stock  received_stock  \
# 0              1             4        5239             12             140
# 1              2             7         768            119             258
# 2              3             1        7122            388              81
# 3              4            12        6943            309             135
# 4              5            12        7254            295              98
# 5              6            21        3715            427             186
# 6              7            24        4376            125              83
# 7              8             8         459            420              16
# 8              9            13        4090            452             234
# 9             10             8        2966             70             260
# 10            11            20        3127            239             270
# 11            12            14        2405             80             232
# ...

# %%
inventory.drop(columns="calculated_closing_stock", inplace=True)

# %%
inventory.head(15)
# Out:
#     inventory_id  warehouse_id  product_id  opening_stock  received_stock  \
# 0              1             4        5239             12             140
# 1              2             7         768            119             258
# 2              3             1        7122            388              81
# 3              4            12        6943            309             135
# 4              5            12        7254            295              98
# 5              6            21        3715            427             186
# 6              7            24        4376            125              83
# 7              8             8         459            420              16
# 8              9            13        4090            452             234
# 9             10             8        2966             70             260
# 10            11            20        3127            239             270
# 11            12            14        2405             80             232
# ...

# %%
inventory[
    ~inventory["warehouse_id"].between(1,25)
]
# Out:
# Empty DataFrame
# Columns: [inventory_id, warehouse_id, product_id, opening_stock, received_stock, sold_stock, returned_stock, damaged_stock, closing_stock, unit_cost, stock_value, last_updated, reorder_flag, warehouse_capacity_utilization]
# Index: []

# %%
inventory[
    inventory["unit_cost"] < 0
]
# Out:
# Empty DataFrame
# Columns: [inventory_id, warehouse_id, product_id, opening_stock, received_stock, sold_stock, returned_stock, damaged_stock, closing_stock, unit_cost, stock_value, last_updated, reorder_flag, warehouse_capacity_utilization]
# Index: []

# %%
# ==========================================
# DUPLICATE RECORDS
# ==========================================

inventory.duplicated().sum()
# Out:
# np.int64(200)

# %%
inventory["inventory_id"].duplicated().sum()
# Out:
# np.int64(200)

# %%
duplicate_count = inventory.duplicated().sum()

if duplicate_count > 0:
    inventory = inventory.drop_duplicates()
    print(f"{duplicate_count} duplicate rows removed.")
else:
    print("No duplicate rows found.")
# Out:
# 200 duplicate rows removed.

# %%
inventory.duplicated().sum()
# Out:
# np.int64(0)

# %%
inventory.isnull().sum()
# Out:
# inventory_id                      0
# warehouse_id                      0
# product_id                        0
# opening_stock                     0
# received_stock                    0
# sold_stock                        0
# returned_stock                    0
# damaged_stock                     0
# closing_stock                     0
# unit_cost                         0
# stock_value                       0
# last_updated                      0
# reorder_flag                      0
# warehouse_capacity_utilization    0
# dtype: int64

# %%
plt.figure(figsize=(6,4))
plt.boxplot(inventory["closing_stock"])
plt.title("Closing Stock")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.boxplot(inventory["stock_value"])
plt.title("Stock Value")
plt.show()

# %%
numerical_columns = [
    "opening_stock",
    "received_stock",
    "sold_stock",
    "returned_stock",
    "damaged_stock",
    "closing_stock",
    "unit_cost",
    "stock_value",
    "warehouse_capacity_utilization"
]

for col in numerical_columns:

    plt.figure(figsize=(6,4))
    plt.boxplot(inventory[col])
    plt.title(col)
    plt.show()

# %%
for col in numerical_columns:

    Q1 = inventory[col].quantile(0.25)
    Q3 = inventory[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = inventory[
        (inventory[col] < lower) |
        (inventory[col] > upper)
    ]

    print(f"{col}: {len(outliers)} outliers")
# Out:
# opening_stock: 0 outliers
# received_stock: 0 outliers
# sold_stock: 0 outliers
# returned_stock: 0 outliers
# damaged_stock: 0 outliers
# closing_stock: 0 outliers
# unit_cost: 0 outliers
# stock_value: 2416 outliers
# warehouse_capacity_utilization: 0 outliers

# %%
Q1 = inventory["stock_value"].quantile(0.25)
Q3 = inventory["stock_value"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

stock_outliers = inventory[
    (inventory["stock_value"] < lower) |
    (inventory["stock_value"] > upper)
]

stock_outliers.head()
# Out:
#      inventory_id  warehouse_id  product_id  opening_stock  received_stock  \
# 80             81            17         817            466             233
# 101           102            24         356            401             266
# 137           138            17         702            499             184
# 182           183            21         962            469             151
# 193           194            22        6329            419             164
#
#      sold_stock  returned_stock  damaged_stock  closing_stock  unit_cost  \
# 80            3               4              6            694    1744.45
# 101          77              14             10            594    1928.77
# 137          17               0              6            660    1749.20
# 182          94               7              3            530    1915.57
# 193          60               9              2            530    1971.68
#
#      stock_value last_updated reorder_flag  warehouse_capacity_utilization
# ...

# %%
stock_outliers[[
    "closing_stock",
    "unit_cost",
    "stock_value"
]].describe()
# Out:
#        closing_stock    unit_cost   stock_value
# count    2416.000000  2416.000000  2.416000e+03
# mean      603.890315  1803.062417  1.083442e+06
# std        64.890281   147.446734  1.026361e+05
# min       482.000000  1293.960000  9.601525e+05
# 25%       553.000000  1712.250000  1.002328e+06
# 50%       598.000000  1832.925000  1.055089e+06
# 75%       649.250000  1922.937500  1.142639e+06
# max       802.000000  1999.740000  1.522832e+06

# %%
# Outliers were detected in stock_value using the IQR method.
# After investigation, these values were found to represent
# legitimate high-value inventory rather than incorrect data.
# Therefore, no outliers were removed.

# %%
sales.columns.tolist()
# Out:
# ['line_id',
#  'order_id',
#  'customer_id',
#  'warehouse_id',
#  'order_date',
#  'shipment_date',
#  'delivery_date',
#  'payment_method',
#  'order_status',
#  'sales_channel',
#  'product_id',
#  'quantity',
#  'unit_price',
#  'discount_percent',
#  'gst_percent',
#  'shipping_cost',
#  'revenue',
#  'profit']

# %%
# ==========================================
sales.head(22)
# Out:
#     line_id  order_id  customer_id  warehouse_id  order_date shipment_date  \
# 0         1         1        41906             4  2024-10-07    2024-11-02
# 1         2         1        41906             4  2024-10-07    2024-11-02
# 2         3         1        41906             4  2024-10-07    2024-11-02
# 3         4         1        41906             4  2024-10-07    2024-11-02
# 4         5         1        41906             4  2024-10-07    2024-11-02
# 5         6         2        23701            19  2026-06-14    2026-06-17
# 6         7         3        24261            12  2026-02-16    2026-06-30
# 7         8         3        24261            12  2026-02-16    2026-06-30
# 8         9         3        24261            12  2026-02-16    2026-06-30
# 9        10         3        24261            12  2026-02-16    2026-06-30
# 10       11         3        24261            12  2026-02-16    2026-06-30
# ...

# %%
sales.columns
# Out:
# Index(['line_id', 'order_id', 'customer_id', 'warehouse_id', 'order_date',
#        'shipment_date', 'delivery_date', 'payment_method', 'order_status',
#        'sales_channel', 'product_id', 'quantity', 'unit_price',
#        'discount_percent', 'gst_percent', 'shipping_cost', 'revenue',
#        'profit'],
#       dtype='object')

# %%
sales.dtypes
# Out:
# line_id               int64
# order_id              int64
# customer_id           int64
# warehouse_id          int64
# order_date           object
# shipment_date        object
# delivery_date        object
# payment_method       object
# order_status         object
# sales_channel        object
# product_id            int64
# quantity              int64
# unit_price          float64
# discount_percent      int64
# gst_percent           int64
# shipping_cost       float64
# revenue             float64
# profit              float64
# dtype: object

# %%
sales.describe()
# Out:
#              line_id       order_id    customer_id   warehouse_id  \
# count  360999.000000  360999.000000  360999.000000  360999.000000
# mean   180354.488727   60035.276242   25027.690930      13.004391
# std    104125.435149   34604.170145   14460.577445       7.204594
# min         1.000000       1.000000       1.000000       1.000000
# 25%     90178.500000   30145.000000   12483.000000       7.000000
# 50%    180357.000000   60003.000000   25031.000000      13.000000
# 75%    270533.500000   90023.500000   37548.000000      19.000000
# max    360699.000000  120000.000000   50000.000000      25.000000
#
#           product_id       quantity     unit_price  discount_percent  \
# count  360999.000000  360999.000000  360999.000000     360999.000000
# mean     3995.559783       5.480223    1260.114273         10.039266
# std      2310.186380       2.877183     714.314662          7.079362
# min         1.000000      -1.000000      25.020000          0.000000
# ...

# %%
sales.columns = (
    sales.columns
        .str.strip()
        .str.lower()
        .str.replace(" ", "_")
)

sales.columns
# Out:
# Index(['line_id', 'order_id', 'customer_id', 'warehouse_id', 'order_date',
#        'shipment_date', 'delivery_date', 'payment_method', 'order_status',
#        'sales_channel', 'product_id', 'quantity', 'unit_price',
#        'discount_percent', 'gst_percent', 'shipping_cost', 'revenue',
#        'profit'],
#       dtype='object')

# %%
text_columns = sales.select_dtypes(include="object").columns

for col in text_columns:
    sales[col] = sales[col].str.strip().str.title()

# %%
sales["payment_method"].value_counts()
# Out:
# payment_method
# Cash           60753
# Upi            60509
# Net Banking    60214
# Wallet         60089
# Credit Card    59945
# Debit Card     59489
# Name: count, dtype: int64

# %%
date_columns = [
    "order_date",
    "shipment_date",
    "delivery_date"
]

for col in date_columns:
    sales[col] = pd.to_datetime(sales[col])

sales.dtypes
# Out:
# line_id                      int64
# order_id                     int64
# customer_id                  int64
# warehouse_id                 int64
# order_date          datetime64[ns]
# shipment_date       datetime64[ns]
# delivery_date       datetime64[ns]
# payment_method              object
# order_status                object
# sales_channel               object
# product_id                   int64
# quantity                     int64
# unit_price                 float64
# discount_percent             int64
# gst_percent                  int64
# shipping_cost              float64
# revenue                    float64
# profit                     float64
# dtype: object

# %%
sales.isnull().sum()
# Out:
# line_id                0
# order_id               0
# customer_id            0
# warehouse_id           0
# order_date             0
# shipment_date          0
# delivery_date          0
# payment_method         0
# order_status           0
# sales_channel          0
# product_id             0
# quantity               0
# unit_price             0
# discount_percent       0
# gst_percent            0
# shipping_cost          0
# revenue             1158
# profit                 0
# dtype: int64

# %%
sales["revenue"] = sales["revenue"].fillna(
    (
        sales["quantity"]
        * sales["unit_price"]
        * (1 - sales["discount_percent"] / 100)
    ).round(2)
)

# %%
sales.isnull().sum()
# Out:
# line_id             0
# order_id            0
# customer_id         0
# warehouse_id        0
# order_date          0
# shipment_date       0
# delivery_date       0
# payment_method      0
# order_status        0
# sales_channel       0
# product_id          0
# quantity            0
# unit_price          0
# discount_percent    0
# gst_percent         0
# shipping_cost       0
# revenue             0
# profit              0
# dtype: int64

# %%
sales.duplicated().sum()
# Out:
# np.int64(300)

# %%
duplicate_count = sales.duplicated().sum()

if duplicate_count > 0:
    sales = sales.drop_duplicates()
    print(f"{duplicate_count} duplicate rows removed.")
else:
    print("No duplicate rows found.")
# Out:
# 300 duplicate rows removed.

# %%
sales[sales["quantity"] <= 0]
# Out:
#         line_id  order_id  customer_id  warehouse_id order_date shipment_date  \
# 42           43        14        11703            19 2025-08-09    2026-07-16
# 87           88        30         5980            16 2025-07-03    2026-03-23
# 162         163        57         3130             8 2024-11-22    2026-06-23
# 1618       1619       528        12805            20 2025-07-09    2026-05-19
# 1903       1904       631        30163            19 2024-07-27    2024-10-01
# ...         ...       ...          ...           ...        ...           ...
# 358416   358417    119255        46882            23 2025-08-23    2025-12-07
# 358715   358716    119354        41700            24 2024-10-30    2025-12-16
# 359427   359428    119591         3947            10 2025-05-24    2026-07-15
# 359682   359683    119673         3164             4 2025-11-25    2026-03-09
# 360582   360583    119965         6524            13 2026-05-05    2026-05-29
#
# ...

# %%
invalid_qty = sales[sales["quantity"] <= 0]

print("Invalid Quantity Rows:", len(invalid_qty))
# Out:
# Invalid Quantity Rows: 734

# %%
sales.loc[sales["quantity"] <= 0, "quantity"] = 1

# %%
sales.loc[:, "revenue"] = (
    sales["quantity"]
    * sales["unit_price"]
    * (1 - sales["discount_percent"] / 100)
).round(2)

# %%
sales[sales["unit_price"] < 0]
# Out:
# Empty DataFrame
# Columns: [line_id, order_id, customer_id, warehouse_id, order_date, shipment_date, delivery_date, payment_method, order_status, sales_channel, product_id, quantity, unit_price, discount_percent, gst_percent, shipping_cost, revenue, profit]
# Index: []

# %%
sales[
    (sales["discount_percent"] < 0) |
    (sales["discount_percent"] > 100)
]
# Out:
# Empty DataFrame
# Columns: [line_id, order_id, customer_id, warehouse_id, order_date, shipment_date, delivery_date, payment_method, order_status, sales_channel, product_id, quantity, unit_price, discount_percent, gst_percent, shipping_cost, revenue, profit]
# Index: []

# %%
sales[
    ~sales["gst_percent"].isin([0,5,12,18])
]
# Out:
# Empty DataFrame
# Columns: [line_id, order_id, customer_id, warehouse_id, order_date, shipment_date, delivery_date, payment_method, order_status, sales_channel, product_id, quantity, unit_price, discount_percent, gst_percent, shipping_cost, revenue, profit]
# Index: []

# %%
sales[
    sales["shipping_cost"] < 0
]
# Out:
# Empty DataFrame
# Columns: [line_id, order_id, customer_id, warehouse_id, order_date, shipment_date, delivery_date, payment_method, order_status, sales_channel, product_id, quantity, unit_price, discount_percent, gst_percent, shipping_cost, revenue, profit]
# Index: []

# %%
sales[
    sales["revenue"] < 0
]
# Out:
# Empty DataFrame
# Columns: [line_id, order_id, customer_id, warehouse_id, order_date, shipment_date, delivery_date, payment_method, order_status, sales_channel, product_id, quantity, unit_price, discount_percent, gst_percent, shipping_cost, revenue, profit]
# Index: []

# %%
sales["line_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
sales[
    sales["shipment_date"] < sales["order_date"]
]
# Out:
# Empty DataFrame
# Columns: [line_id, order_id, customer_id, warehouse_id, order_date, shipment_date, delivery_date, payment_method, order_status, sales_channel, product_id, quantity, unit_price, discount_percent, gst_percent, shipping_cost, revenue, profit]
# Index: []

# %%
sales[
    sales["delivery_date"] < sales["shipment_date"]
]
# Out:
# Empty DataFrame
# Columns: [line_id, order_id, customer_id, warehouse_id, order_date, shipment_date, delivery_date, payment_method, order_status, sales_channel, product_id, quantity, unit_price, discount_percent, gst_percent, shipping_cost, revenue, profit]
# Index: []

# %%
sales[
    sales["profit"] > sales["revenue"]
]
# Out:
#         line_id  order_id  customer_id  warehouse_id order_date shipment_date  \
# 42           43        14        11703            19 2025-08-09    2026-07-16
# 1618       1619       528        12805            20 2025-07-09    2026-05-19
# 1903       1904       631        30163            19 2024-07-27    2024-10-01
# 2086       2087       699        38411             3 2025-10-29    2025-12-01
# 5176       5177      1736        17655             5 2024-09-27    2025-10-03
# ...         ...       ...          ...           ...        ...           ...
# 358415   358416    119254        37630             1 2026-06-22    2026-07-09
# 358416   358417    119255        46882            23 2025-08-23    2025-12-07
# 359427   359428    119591         3947            10 2025-05-24    2026-07-15
# 359682   359683    119673         3164             4 2025-11-25    2026-03-09
# 360582   360583    119965         6524            13 2026-05-05    2026-05-29
#
# ...

# %%
mask = sales["profit"] > sales["revenue"]

sales.loc[mask, "profit"] = (
    sales.loc[mask, "revenue"] * 0.20
).round(2)

# %%
(sales["profit"] > sales["revenue"]).sum()
# Out:
# np.int64(0)

# %%
numerical_columns = [
    "quantity",
    "unit_price",
    "shipping_cost",
    "revenue",
    "profit"
]
for col in numerical_columns:

    plt.figure(figsize=(6,4))
    plt.boxplot(sales[col])
    plt.title(col)
    plt.show()

# %%
for col in numerical_columns:

    Q1 = sales[col].quantile(0.25)
    Q3 = sales[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = sales[
        (sales[col] < lower) |
        (sales[col] > upper)
    ]

    print(f"{col}: {len(outliers)} outliers")
# Out:
# quantity: 0 outliers
# unit_price: 0 outliers
# shipping_cost: 0 outliers
# revenue: 4471 outliers
# profit: 13655 outliers

# %%
print("Negative Quantity :", (sales["quantity"] <= 0).sum())
print("Negative Revenue  :", (sales["revenue"] < 0).sum())
print("Profit > Revenue  :", (sales["profit"] > sales["revenue"]).sum())
print("Invalid Discount  :", ((sales["discount_percent"] < 0) | (sales["discount_percent"] > 100)).sum())
print("Invalid GST       :", (~sales["gst_percent"].isin([0, 5, 12, 18])).sum())
# Out:
# Negative Quantity : 0
# Negative Revenue  : 0
# Profit > Revenue  : 0
# Invalid Discount  : 0
# Invalid GST       : 0

# %%
# Revenue and Profit show statistical outliers according to the IQR method.
# These represent legitimate high-value sales transactions rather than
# data quality issues, so they were retained.

# %%
from sqlalchemy import create_engine

# %%
username = "postgres"
password = "Akshay1901"
host = "localhost"
port = "5432"
database = "Suppy-Chain & Inventory Analysis"

engine = create_engine(
    f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
)
products.to_sql(
    "products",
    engine,
    if_exists="replace",
    index=False
)
suppliers.to_sql(
    "suppliers",
    engine,
    if_exists="replace",
    index=False
)
customers.to_sql(
    "customers",
    engine,
    if_exists="replace",
    index=False
)
inventory.to_sql(
    "inventory",
    engine,
    if_exists="replace",
    index=False
)
sales.to_sql(
    "sales",
    engine,
    if_exists="replace",
    index=False
)

print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")

# %%
from sqlalchemy import inspect

inspector = inspect(engine)

print(inspector.get_table_names())
# Out:
# ['products', 'suppliers', 'customers', 'inventory', 'sales']
